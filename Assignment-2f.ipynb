# %%
import tensorflow as tf
import keras

# %%
from keras.models import Sequential
from keras.datasets import mnist
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %%
keras.__version__
# Out:
# '3.11.3'

# %%
tf.__version__
# Out:
# '2.20.0'

# %%
X_train = X_train/255
X_test = X_test/255

# %% [markdown]
# # Creating a model

# %%
model = Sequential()
model.add(keras.layers.Flatten(input_shape=(28,28)))
model.add(keras.layers.Dense(128, activation="relu"))
#model.add(keras.layers.Dense(64, activation="relu"))
model.add(keras.layers.Dense(10, activation="softmax"))
# Out:
# C:\Users\jayes\anaconda3\envs\py311_env\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer="sgd", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

# %%
history=model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8415 - loss: 0.6402 - val_accuracy: 0.9033 - val_loss: 0.3561
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9047 - loss: 0.3374 - val_accuracy: 0.9177 - val_loss: 0.2927
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9184 - loss: 0.2890 - val_accuracy: 0.9273 - val_loss: 0.2609
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9279 - loss: 0.2583 - val_accuracy: 0.9321 - val_loss: 0.2378
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9343 - loss: 0.2351 - val_accuracy: 0.9351 - val_loss: 0.2205
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9400 - loss: 0.2160 - val_accuracy: 0.9416 - val_loss: 0.2043
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9441 - loss: 0.2001 - val_accuracy: 0.9448 - val_loss: 0.1931
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9482 - loss: 0.1866 - val_accuracy: 0.9480 - val_loss: 0.1812
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9514 - loss: 0.1752 - val_accuracy: 0.9497 - val_loss: 0.1723
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9541 - loss: 0.1649 - val_accuracy: 0.9529 - val_loss: 0.1631

# %%
plt.plot(history.history['loss'],label='training loss')
plt.legend()
plt.show()

# %% [markdown]
# # Evaluate the model

# %%
plt.plot(history.history['accuracy'],label='accuracy')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"Loss: {test_loss}")
print(f"Acc: {test_acc}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9529 - loss: 0.1631
# Loss: 0.16312116384506226
# Acc: 0.9528999924659729

# %%
n = random.randint(0, 999)

# %%
plt.imshow(X_test[n])
plt.show()

# %%
prediction = model.predict(X_test)

print(f"Digit: {np.argmax(prediction[n])}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Digit: 1
